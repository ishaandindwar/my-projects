# %% [markdown]
# <a href="https://colab.research.google.com/github/ishaandindwar/my-projects/blob/main/sentiment_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
sentiment_analyzer = pipeline("sentiment-analysis")
model = "distilbert-base-uncased-finetuned-sst-2-english"
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
sentence = "Messi is the greatest"
result = sentiment_analyzer(sentence)
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998195767402649}]

# %%
dataset = [
    "I love football",
    "I love messi",
    "I am not a fan of Ronaldo",
    "Football is very hard to play",
    "I am descent at it!"
]
results = sentiment_analyzer(dataset)
print(results)
for sentence, result in zip(dataset, results):
  print(f"Sentence:{sentence}")
  print(f"Sentiment: {result['label']} (Confidence: {result['score']:.4f})\n")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9996902942657471}, {'label': 'POSITIVE', 'score': 0.999210000038147}, {'label': 'NEGATIVE', 'score': 0.9966099858283997}, {'label': 'NEGATIVE', 'score': 0.9986624717712402}, {'label': 'POSITIVE', 'score': 0.8654084801673889}]
# Sentence:I love football
# Sentiment: POSITIVE (Confidence: 0.9997)
#
# Sentence:I love messi
# Sentiment: POSITIVE (Confidence: 0.9992)
#
# Sentence:I am not a fan of Ronaldo
# Sentiment: NEGATIVE (Confidence: 0.9966)
#
# Sentence:Football is very hard to play
# Sentiment: NEGATIVE (Confidence: 0.9987)
#
# Sentence:I am descent at it!
# Sentiment: POSITIVE (Confidence: 0.8654)
